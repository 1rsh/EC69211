# %% [markdown]
# # Experiment 5 | EC69211 | Image and Video Processing Laboratory
# **Author:** Irsh Vijay | 21EC39055

# %%
# %load_ext autoreload
# %autoreload 2

from imagestack import ImageStack, ImageStackLazy
from ui import UI

# %%
img = ImageStack("Noisy Images")

# %%
filter_args={"filter_size": 3}
name = "mean"
img.plot_transformed(None, name, filter_args, image_idx=1)
# Out:
# Cache is being prepared in parallel! Reverting to computing in callback!

# %%
filter_args={"filter_size": 3}
name = "mean"
img.plot_transformed(None, name, filter_args, image_idx=1)
# Out:
# Cache is being prepared in parallel! Reverting to computing in callback!

# %%
filter_args={"filter_size": 19, "sigma": 10}
img.plot_transformed(None, "gaussian", filter_args, image_idx=5)
# Out:
# Cache is being prepared in parallel! Reverting to computing in callback!

# %%
filter_args={"filter_size": 3, "sigma": 1}
img.plot_gaussian_unblur(img.stack[5], filter_args, epsilon=5e-2)

# %%
ui = UI()

ui.show()
# Out:
# HTML(value='<h1>Experiment 5 | UI with Multi-Core Precompute</h1>')
# HTML(value='<h3>Irsh Vijay | 21EC39055 <br> Choose a folder, select an image, apply filters, and view the resu…
# Text(value='', description='Folder Path:', layout=Layout(height='40px', width='50%'), placeholder='Enter folde…
# Dropdown(description='Select Image:', layout=Layout(height='40px', width='50%'), options=(), value=None)
# Dropdown(description='Filter Name:', index=4, layout=Layout(height='40px', width='50%'), options=('mean', 'med…
# Label(value='Filter Size: 7', layout=Layout(display='none', height='30px', width='50%'))
# IntSlider(value=7, description='Filter Size:', layout=Layout(display='none', height='50px', width='50%'), max=…
# Label(value='Sigma: 3', layout=Layout(display='none', height='30px', width='50%'))
# IntSlider(value=3, description='Sigma:', layout=Layout(display='none', height='50px', width='50%'), max=7, min…
# Output()
